# %%
import pandas as pd
import pickle

with open('/content/drive/MyDrive/deepfish/localize_fish/loc_results/score_list_paspp_fcn_wide_resnet50.pkl', 'rb') as f:
    data = pickle.load(f)

#print(data)
df = pd.DataFrame(data)
print(df.to_string())
# Out:
#     epoch    val_loc  GAME_score      GAME1      GAME2      GAME3      GAME4      GAME5      GAME6  loss_loc
# 0       0  34.803125    0.055452  34.803125  35.353125  36.303125  36.956250  35.687500  33.834375  3.627798
# 1       1   0.984375    0.002173   0.984375   1.196875   1.337500   1.462500   1.606250   1.757812  2.598943
# 2       2   0.964063    0.002428   0.964063   1.235937   1.410937   1.610937   1.845312   2.254688  1.668991
# 3       3   0.675000    0.001725   0.675000   0.846875   0.946875   1.090625   1.312500   1.751562  1.527270
# 4       4   1.070312    0.002551   1.070312   1.307813   1.479688   1.664062   1.889063   2.384375  1.209871
# 5       5   0.578125    0.001526   0.578125   0.693750   0.796875   0.962500   1.196875   1.632812  1.249262
# 6       6   0.517188    0.001211   0.517188   0.576562   0.626563   0.723437   0.901563   1.303125  1.076169
# 7       7   0.887500    0.002066   0.887500   1.050000   1.159375   1.293750   1.556250   1.985937  0.954104
# ...
